# %%
#import depencies
import pandas as pd
from sqlalchemy import create_engine
import psycopg2
import matplotlib.pyplot as plt

#create engine and link to postgres
engine = create_engine('postgresql://postgres:postgres@localhost/Seinfeld_etl')
connection = engine.connect()

# %%
#show Episode_info table to see column titles
Info = pd.read_sql("SELECT * FROM Episode_info", connection)
Info.head()
# Out:
#    season  episodeno              title     airdate  \
# 0       1          1       The Stakeout  1990-05-31
# 1       1          2        The Robbery  1990-06-07
# 2       1          3     Male Unbonding  1990-06-14
# 3       1          4      The Stock Tip  1990-06-21
# 4       2          1  The Ex-Girlfriend  1991-01-16
#
#                        writers      director   seid
# 0  Larry David, Jerry Seinfeld  Tom Cherones  S1E01
# 1                 Matt Goldman  Tom Cherones  S1E02
# 2  Larry David, Jerry Seinfeld  Tom Cherones  S1E03
# 3  Larry David, Jerry Seinfeld  Tom Cherones  S1E04
# 4  Larry David, Jerry Seinfeld  Tom Cherones  S2E01

# %%
#show Episode_info table to see column titles
Wiki = pd.read_sql("SELECT * FROM Wiki_Data", connection)
Wiki.head()
# Out:
#     seid  production_id viewercount  ident
# 0  S1E01            101        15.4      1
# 1  S1E02            103        22.5      2
# 2  S1E03            104        19.7      3
# 3  S1E04            102        19.1      4
# 4  S1E05            105        19.4      5

# %%
Merge_df = pd.merge (Info, Wiki, on="seid")
Merge_df.head()
# Out:
#    season  episodeno              title     airdate  \
# 0       1          1       The Stakeout  1990-05-31
# 1       1          2        The Robbery  1990-06-07
# 2       1          3     Male Unbonding  1990-06-14
# 3       1          4      The Stock Tip  1990-06-21
# 4       2          1  The Ex-Girlfriend  1991-01-16
#
#                        writers      director   seid  production_id  \
# 0  Larry David, Jerry Seinfeld  Tom Cherones  S1E01            101
# 1                 Matt Goldman  Tom Cherones  S1E02            103
# 2  Larry David, Jerry Seinfeld  Tom Cherones  S1E03            104
# 3  Larry David, Jerry Seinfeld  Tom Cherones  S1E04            102
# 4  Larry David, Jerry Seinfeld  Tom Cherones  S2E01            201
#
#   viewercount  ident
# 0        15.4      1
# 1        22.5      2
# 2        19.7      3
# 3        19.1      4
# 4        15.6      6

# %%
Script = pd.read_sql("SELECT * FROM Scripts", connection)
Script.head()
# Out:
#   character_name                                           dialogue  \
# 0          JERRY  Do you know what this is all about? Do you kno...
# 1          JERRY  (pointing at Georges shirt) See, to me, that b...
# 2         GEORGE                                   Are you through?
# 3          JERRY             You do of course try on, when you buy?
# 4         GEORGE  Yes, it was purple, I liked it, I dont actuall...
#
#    episodeno   seid  season
# 0          1  PILOT       1
# 1          1  PILOT       1
# 2          1  PILOT       1
# 3          1  PILOT       1
# 4          1  PILOT       1
