# %%
# Import Dependencies
import pandas as pd

# %%
# Create a DataFrame of paintings using a list of dictionaries
WikiDataDF = pd.DataFrame([
    {"SEID":"S1E01","ProductionID":"101","USViewerCountMil":"15.4"},
    {"SEID":"S1E02","ProductionID":"103","USViewerCountMil":"22.5"},
    {"SEID":"S1E03","ProductionID":"104","USViewerCountMil":"19.7"},
    {"SEID":"S1E04","ProductionID":"102","USViewerCountMil":"19.1"},
    {"SEID":"S1E05","ProductionID":"105","USViewerCountMil":"19.4"},
    {"SEID":"S2E01","ProductionID":"201","USViewerCountMil":"15.6"},
    {"SEID":"S2E02","ProductionID":"202","USViewerCountMil":"15.2"},
    {"SEID":"S2E03","ProductionID":"205","USViewerCountMil":"14.8"},
    {"SEID":"S2E04","ProductionID":"207","USViewerCountMil":"13.6"},
    {"SEID":"S2E05","ProductionID":"208","USViewerCountMil":"24.7"},
    {"SEID":"S2E06","ProductionID":"210","USViewerCountMil":"23.3"},
    {"SEID":"S2E07","ProductionID":"212","USViewerCountMil":"19.6"},
    {"SEID":"S2E08","ProductionID":"211","USViewerCountMil":"20.6"},
    {"SEID":"S2E09","ProductionID":"213","USViewerCountMil":"22.9"},
    {"SEID":"S2E10","ProductionID":"204","USViewerCountMil":"17.2"},
    {"SEID":"S2E11","ProductionID":"206","USViewerCountMil":"16.8"},
    {"SEID":"S2E12","ProductionID":"203","USViewerCountMil":"12.5"}
])
WikiDataDF
# Out:
#      SEID ProductionID USViewerCountMil
# 0   S1E01          101             15.4
# 1   S1E02          103             22.5
# 2   S1E03          104             19.7
# 3   S1E04          102             19.1
# 4   S1E05          105             19.4
# 5   S2E01          201             15.6
# 6   S2E02          202             15.2
# 7   S2E03          205             14.8
# 8   S2E04          207             13.6
# 9   S2E05          208             24.7
# 10  S2E06          210             23.3
# 11  S2E07          212             19.6
# 12  S2E08          211             20.6
# 13  S2E09          213             22.9
# 14  S2E10          204             17.2
# 15  S2E11          206             16.8
# 16  S2E12          203             12.5

# %%
WikiDataDF.Head()
